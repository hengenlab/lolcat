# %%
from torch.utils.data import DataLoader
import torch
import torch.nn.functional as F
import torch.optim as optim

import sys
sys.path.append('../')

from src import Dataset, EdgeDistributionDataset
from src.network import MLP

# %% [markdown]
# ### Loading dataset

# %%
dataset = Dataset('../data', force_process=False)
aggr_dict = {'e23Cux2': 'e23', 'i5Sst': 'i5Sst', 'i5Htr3a': 'i5Htr3a', 'e4Scnn1a': 'e4', 'e4Rorb': 'e4',
             'e4other': 'e4', 'e4Nr5a1': 'e4', 'i6Htr3a': 'i6Htr3a', 'i6Sst': 'i6Sst', 'e6Ntsr1': 'e6',
             'i23Pvalb': 'i23Pvalb', 'i23Htr3a': 'i23Htr3a', 'i1Htr3a': 'i1Htr3a', 'i4Sst': 'i4Sst', 'e5Rbp4': 'e5',
             'e5noRbp4': 'e5', 'i23Sst': 'i23Sst', 'i4Htr3a': 'i4Htr3a', 'i6Pvalb': 'i6Pvalb', 'i5Pvalb': 'i5Pvalb',
             'i4Pvalb': 'i4Pvalb'}
dataset.aggregate_cell_classes(aggr_dict)
# Split into train/val/test sets
dataset.split_cell_train_val_test(test_size=0.2, val_size=0.2, seed=1234)
dataset.split_trial_train_val_test(test_size=0.2, val_size=0.2, temp=True, seed=1234)

# bining
dataset.set_bining_parameters(bin_size=0.1) # in seconds, so this is 10ms
# Out:
# Found processed pickle. Loading from '../data/processed/dataset.pkl'.

# %%
# Create Pytorch datasets
train_dataset = ISIDistributionDataset(dataset, edge_dist_num_bins=10, mode='train', sampler='U20')
# fix population for validation set and test set (they will be different of course)
val_dataset = EdgeDistributionDataset(dataset, edge_dist_num_bins=10, mode='val', sampler='U20', cell_random_seed=1)
test_dataset = EdgeDistributionDataset(dataset, edge_dist_num_bins=10, mode='test', sampler='U20', cell_random_seed=1)

train_loader = DataLoader(train_dataset, shuffle=True, batch_size=5, collate_fn=train_dataset.collate_fn)
val_loader = DataLoader(val_dataset, batch_size=1, collate_fn=train_dataset.collate_fn)
test_loader = DataLoader(test_dataset, batch_size=1, collate_fn=train_dataset.collate_fn)

# %%
print(test_dataset)
# Out:
# <src.pytorch_dataset.EdgeDistributionDataset object at 0x7faff759b3d0>

# %%
def train(model, device, train_loader, optimizer, epoch, log_interval=None):
    model.train()
    for batch_idx, (data, target) in enumerate(train_loader):
        data, target = data.to(device), target.to(device)
        optimizer.zero_grad()
        output = model(data)
        loss = F.nll_loss(output, target)
        loss.backward()
        optimizer.step()
        if log_interval and batch_idx % log_interval == 0:
            print('Train Epoch: {} [({:.0f}%)]\tLoss: {:.6f}'.format(
                epoch, 100. * batch_idx / len(train_loader), loss.item()))

def test(model, device, loader, tag):
    model.eval()
    test_loss = 0
    correct = 0
    total = 0
    with torch.no_grad():
        for data, target in loader:
            data, target = data.to(device), target.to(device)
            output = model(data)
            test_loss += F.nll_loss(output, target, reduction='sum').item()  # sum up batch loss
            pred = output.argmax(dim=1, keepdim=True)  # get the index of the max log-probability
            correct += pred.eq(target.view_as(pred)).sum().item()
            total += len(target)

    print('{} set: Accuracy: {}/{} ({:.0f}%)'.format(tag,
        correct, total,
        100. * correct / total))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

model = MLP(input_dims=train_dataset.num_bins, n_hiddens=[20, 20, 20], n_class=17, dropout_p=0.2).to(device)
print(model)

lr = 1e-2
optimizer = optim.Adam(model.parameters(), lr=lr)

epochs=100
for epoch in range(1, epochs + 1):
    train(model, device, train_loader, optimizer, epoch, log_interval=5)
    test(model, device, train_loader, 'Train')
    test(model, device, val_loader, 'Val')
    test(model, device, test_loader, 'Test')
    print('\n')
# Out:
# MLP(
#   (model): Sequential(
#     (fc1): Linear(in_features=10, out_features=20, bias=True)
#     (relu1): ReLU()
#     (drop1): Dropout(p=0.2, inplace=False)
#     (fc2): Linear(in_features=20, out_features=20, bias=True)
#     (relu2): ReLU()
#     (drop2): Dropout(p=0.2, inplace=False)
#     (fc3): Linear(in_features=20, out_features=20, bias=True)
#     (relu3): ReLU()
#     (drop3): Dropout(p=0.2, inplace=False)
#     (out): Linear(in_features=20, out_features=17, bias=True)
#   )
# )
# Train Epoch: 1 [(0%)]	Loss: 9.066427
# Train Epoch: 1 [(42%)]	Loss: 3.075309
# Train Epoch: 1 [(83%)]	Loss: 2.850359
# Train set: Accuracy: 2011/20400 (10%)
# Val set: Accuracy: 609/6800 (9%)
# Test set: Accuracy: 713/6800 (10%)
#
#
# Train Epoch: 2 [(0%)]	Loss: 2.836290
# Train Epoch: 2 [(42%)]	Loss: 2.826132
# Train Epoch: 2 [(83%)]	Loss: 2.817297
# Train set: Accuracy: 1550/20400 (8%)
# Val set: Accuracy: 515/6800 (8%)
# Test set: Accuracy: 498/6800 (7%)
#
#
# Train Epoch: 3 [(0%)]	Loss: 2.799865
# Train Epoch: 3 [(42%)]	Loss: 2.785947
# Train Epoch: 3 [(83%)]	Loss: 2.782158
# Train set: Accuracy: 2032/20400 (10%)
# Val set: Accuracy: 691/6800 (10%)
# Test set: Accuracy: 715/6800 (11%)
#
#
# Train Epoch: 4 [(0%)]	Loss: 2.757615
# Train Epoch: 4 [(42%)]	Loss: 2.763428
# Train Epoch: 4 [(83%)]	Loss: 2.757966
# Train set: Accuracy: 2024/20400 (10%)
# Val set: Accuracy: 632/6800 (9%)
# Test set: Accuracy: 677/6800 (10%)
#
#
# Train Epoch: 5 [(0%)]	Loss: 2.766331
# Train Epoch: 5 [(42%)]	Loss: 2.758627
# Train Epoch: 5 [(83%)]	Loss: 2.750700
# Train set: Accuracy: 2171/20400 (11%)
# Val set: Accuracy: 744/6800 (11%)
# Test set: Accuracy: 776/6800 (11%)
#
#
# Train Epoch: 6 [(0%)]	Loss: 2.738739
# Train Epoch: 6 [(42%)]	Loss: 2.740715
# Train Epoch: 6 [(83%)]	Loss: 2.738381
# Train set: Accuracy: 2196/20400 (11%)
# Val set: Accuracy: 753/6800 (11%)
# Test set: Accuracy: 764/6800 (11%)
#
#
# Train Epoch: 7 [(0%)]	Loss: 2.724005
# Train Epoch: 7 [(42%)]	Loss: 2.726118
# Train Epoch: 7 [(83%)]	Loss: 2.713386
# Train set: Accuracy: 2186/20400 (11%)
# Val set: Accuracy: 754/6800 (11%)
# Test set: Accuracy: 760/6800 (11%)
#
#
# Train Epoch: 8 [(0%)]	Loss: 2.717948
# Train Epoch: 8 [(42%)]	Loss: 2.727911
# Train Epoch: 8 [(83%)]	Loss: 2.713211
# Train set: Accuracy: 2176/20400 (11%)
# Val set: Accuracy: 765/6800 (11%)
# Test set: Accuracy: 760/6800 (11%)
#
#
# Train Epoch: 9 [(0%)]	Loss: 2.696604
# Train Epoch: 9 [(42%)]	Loss: 2.712692
# Train Epoch: 9 [(83%)]	Loss: 2.696696
# Train set: Accuracy: 2190/20400 (11%)
# Val set: Accuracy: 757/6800 (11%)
# Test set: Accuracy: 765/6800 (11%)
#
#
# Train Epoch: 10 [(0%)]	Loss: 2.692790
# Train Epoch: 10 [(42%)]	Loss: 2.703965
# Train Epoch: 10 [(83%)]	Loss: 2.697869
# Train set: Accuracy: 2166/20400 (11%)
# Val set: Accuracy: 749/6800 (11%)
# Test set: Accuracy: 758/6800 (11%)
#
#
# Train Epoch: 11 [(0%)]	Loss: 2.691326
# Train Epoch: 11 [(42%)]	Loss: 2.701515
# Train Epoch: 11 [(83%)]	Loss: 2.684945
# Train set: Accuracy: 2151/20400 (11%)
# Val set: Accuracy: 750/6800 (11%)
# Test set: Accuracy: 758/6800 (11%)
#
#
# Train Epoch: 12 [(0%)]	Loss: 2.715638
# Train Epoch: 12 [(42%)]	Loss: 2.707044
# Train Epoch: 12 [(83%)]	Loss: 2.690761
# Train set: Accuracy: 2152/20400 (11%)
# Val set: Accuracy: 754/6800 (11%)
# Test set: Accuracy: 760/6800 (11%)
#
#
# Train Epoch: 13 [(0%)]	Loss: 2.691007
# Train Epoch: 13 [(42%)]	Loss: 2.726401
# Train Epoch: 13 [(83%)]	Loss: 2.684964
# Train set: Accuracy: 2187/20400 (11%)
# Val set: Accuracy: 759/6800 (11%)
# Test set: Accuracy: 761/6800 (11%)
#
#
# Train Epoch: 14 [(0%)]	Loss: 2.696100
# Train Epoch: 14 [(42%)]	Loss: 2.708771
# Train Epoch: 14 [(83%)]	Loss: 2.693431
# Train set: Accuracy: 2171/20400 (11%)
# Val set: Accuracy: 753/6800 (11%)
# Test set: Accuracy: 760/6800 (11%)
#
#
# Train Epoch: 15 [(0%)]	Loss: 2.702102
# Train Epoch: 15 [(42%)]	Loss: 2.705762
# Train Epoch: 15 [(83%)]	Loss: 2.701679
# Train set: Accuracy: 2172/20400 (11%)
# Val set: Accuracy: 759/6800 (11%)
# Test set: Accuracy: 762/6800 (11%)
#
#
# Train Epoch: 16 [(0%)]	Loss: 2.696616
# Train Epoch: 16 [(42%)]	Loss: 2.706707
# Train Epoch: 16 [(83%)]	Loss: 2.683177
# Train set: Accuracy: 2186/20400 (11%)
# Val set: Accuracy: 748/6800 (11%)
# Test set: Accuracy: 758/6800 (11%)
#
#
# Train Epoch: 17 [(0%)]	Loss: 2.703211
# Train Epoch: 17 [(42%)]	Loss: 2.705369
# Train Epoch: 17 [(83%)]	Loss: 2.696128
# Train set: Accuracy: 2185/20400 (11%)
# Val set: Accuracy: 744/6800 (11%)
# Test set: Accuracy: 765/6800 (11%)
#
#
# Train Epoch: 18 [(0%)]	Loss: 2.684267
# Train Epoch: 18 [(42%)]	Loss: 2.715448
# Train Epoch: 18 [(83%)]	Loss: 2.697109
# Train set: Accuracy: 2186/20400 (11%)
# Val set: Accuracy: 747/6800 (11%)
# Test set: Accuracy: 764/6800 (11%)
#
#
# Train Epoch: 19 [(0%)]	Loss: 2.693112
# Train Epoch: 19 [(42%)]	Loss: 2.717972
# Train Epoch: 19 [(83%)]	Loss: 2.693066
# Train set: Accuracy: 2194/20400 (11%)
# Val set: Accuracy: 766/6800 (11%)
# Test set: Accuracy: 768/6800 (11%)
#
#
# Train Epoch: 20 [(0%)]	Loss: 2.686026
# Train Epoch: 20 [(42%)]	Loss: 2.708621
# Train Epoch: 20 [(83%)]	Loss: 2.693881
# Train set: Accuracy: 2442/20400 (12%)
# Val set: Accuracy: 795/6800 (12%)
# Test set: Accuracy: 785/6800 (12%)
#
#
# Train Epoch: 21 [(0%)]	Loss: 2.691402
# Train Epoch: 21 [(42%)]	Loss: 2.702082
# Train Epoch: 21 [(83%)]	Loss: 2.688600
# Train set: Accuracy: 2241/20400 (11%)
# Val set: Accuracy: 764/6800 (11%)
# Test set: Accuracy: 779/6800 (11%)
#
#
# Train Epoch: 22 [(0%)]	Loss: 2.685338
# Train Epoch: 22 [(42%)]	Loss: 2.697001
# Train Epoch: 22 [(83%)]	Loss: 2.686177
# Train set: Accuracy: 2160/20400 (11%)
# Val set: Accuracy: 663/6800 (10%)
# Test set: Accuracy: 739/6800 (11%)
#
#
# Train Epoch: 23 [(0%)]	Loss: 2.689955
# Train Epoch: 23 [(42%)]	Loss: 2.692924
# Train Epoch: 23 [(83%)]	Loss: 2.684879
# Train set: Accuracy: 2386/20400 (12%)
# Val set: Accuracy: 815/6800 (12%)
# Test set: Accuracy: 756/6800 (11%)
#
#
# Train Epoch: 24 [(0%)]	Loss: 2.684103
# Train Epoch: 24 [(42%)]	Loss: 2.694778
# Train Epoch: 24 [(83%)]	Loss: 2.667955
# Train set: Accuracy: 2531/20400 (12%)
# Val set: Accuracy: 835/6800 (12%)
# Test set: Accuracy: 779/6800 (11%)
#
#
# Train Epoch: 25 [(0%)]	Loss: 2.682783
# Train Epoch: 25 [(42%)]	Loss: 2.707918
# Train Epoch: 25 [(83%)]	Loss: 2.685509
# Train set: Accuracy: 2502/20400 (12%)
# Val set: Accuracy: 802/6800 (12%)
# Test set: Accuracy: 774/6800 (11%)
#
#
# Train Epoch: 26 [(0%)]	Loss: 2.690836
# Train Epoch: 26 [(42%)]	Loss: 2.693658
# Train Epoch: 26 [(83%)]	Loss: 2.670519
# Train set: Accuracy: 2361/20400 (12%)
# Val set: Accuracy: 703/6800 (10%)
# Test set: Accuracy: 726/6800 (11%)
#
#
# Train Epoch: 27 [(0%)]	Loss: 2.677544
# Train Epoch: 27 [(42%)]	Loss: 2.676580
# Train Epoch: 27 [(83%)]	Loss: 2.680184
# Train set: Accuracy: 2385/20400 (12%)
# Val set: Accuracy: 825/6800 (12%)
# Test set: Accuracy: 774/6800 (11%)
#
#
# Train Epoch: 28 [(0%)]	Loss: 2.688103
# Train Epoch: 28 [(42%)]	Loss: 2.688817
# Train Epoch: 28 [(83%)]	Loss: 2.667849
# Train set: Accuracy: 2377/20400 (12%)
# Val set: Accuracy: 705/6800 (10%)
# Test set: Accuracy: 719/6800 (11%)
#
#
# Train Epoch: 29 [(0%)]	Loss: 2.673136
# Train Epoch: 29 [(42%)]	Loss: 2.692537
# Train Epoch: 29 [(83%)]	Loss: 2.698418
# Train set: Accuracy: 2537/20400 (12%)
# Val set: Accuracy: 825/6800 (12%)
# Test set: Accuracy: 778/6800 (11%)
#
#
# Train Epoch: 30 [(0%)]	Loss: 2.680753
# Train Epoch: 30 [(42%)]	Loss: 2.678624
# Train Epoch: 30 [(83%)]	Loss: 2.693202
# Train set: Accuracy: 2480/20400 (12%)
# Val set: Accuracy: 777/6800 (11%)
# Test set: Accuracy: 804/6800 (12%)
#
#
# Train Epoch: 31 [(0%)]	Loss: 2.676008
# Train Epoch: 31 [(42%)]	Loss: 2.695010
# Train Epoch: 31 [(83%)]	Loss: 2.675828
# Train set: Accuracy: 2601/20400 (13%)
# Val set: Accuracy: 775/6800 (11%)
# Test set: Accuracy: 798/6800 (12%)
#
#
# Train Epoch: 32 [(0%)]	Loss: 2.671608
# Train Epoch: 32 [(42%)]	Loss: 2.690206
# Train Epoch: 32 [(83%)]	Loss: 2.673753
# Train set: Accuracy: 2531/20400 (12%)
# Val set: Accuracy: 697/6800 (10%)
# Test set: Accuracy: 749/6800 (11%)
#
#
# Train Epoch: 33 [(0%)]	Loss: 2.663327
# Train Epoch: 33 [(42%)]	Loss: 2.695925
# Train Epoch: 33 [(83%)]	Loss: 2.655762
# Train set: Accuracy: 2516/20400 (12%)
# Val set: Accuracy: 811/6800 (12%)
# Test set: Accuracy: 783/6800 (12%)
#
#
# Train Epoch: 34 [(0%)]	Loss: 2.651075
# Train Epoch: 34 [(42%)]	Loss: 2.686875
# Train Epoch: 34 [(83%)]	Loss: 2.675735
# Train set: Accuracy: 2303/20400 (11%)
# Val set: Accuracy: 595/6800 (9%)
# Test set: Accuracy: 596/6800 (9%)
#
#
# Train Epoch: 35 [(0%)]	Loss: 2.678958
# Train Epoch: 35 [(42%)]	Loss: 2.676208
# Train Epoch: 35 [(83%)]	Loss: 2.654668
# Train set: Accuracy: 2542/20400 (12%)
# Val set: Accuracy: 683/6800 (10%)
# Test set: Accuracy: 766/6800 (11%)
#
#
# Train Epoch: 36 [(0%)]	Loss: 2.659614
# Train Epoch: 36 [(42%)]	Loss: 2.687201
# Train Epoch: 36 [(83%)]	Loss: 2.656446
# Train set: Accuracy: 2569/20400 (13%)
# Val set: Accuracy: 738/6800 (11%)
# Test set: Accuracy: 819/6800 (12%)
#
#
# Train Epoch: 37 [(0%)]	Loss: 2.663428
# Train Epoch: 37 [(42%)]	Loss: 2.675514
# Train Epoch: 37 [(83%)]	Loss: 2.648558
# Train set: Accuracy: 2596/20400 (13%)
# Val set: Accuracy: 813/6800 (12%)
# Test set: Accuracy: 791/6800 (12%)
#
#
# Train Epoch: 38 [(0%)]	Loss: 2.658843
# Train Epoch: 38 [(42%)]	Loss: 2.675109
# Train Epoch: 38 [(83%)]	Loss: 2.643623
# Train set: Accuracy: 2465/20400 (12%)
# Val set: Accuracy: 745/6800 (11%)
# Test set: Accuracy: 633/6800 (9%)
#
#
# Train Epoch: 39 [(0%)]	Loss: 2.649498
# Train Epoch: 39 [(42%)]	Loss: 2.693645
# Train Epoch: 39 [(83%)]	Loss: 2.668823
# Train set: Accuracy: 2652/20400 (13%)
# Val set: Accuracy: 818/6800 (12%)
# Test set: Accuracy: 812/6800 (12%)
#
#
# Train Epoch: 40 [(0%)]	Loss: 2.669248
# Train Epoch: 40 [(42%)]	Loss: 2.662104
# Train Epoch: 40 [(83%)]	Loss: 2.667368
# Train set: Accuracy: 2639/20400 (13%)
# Val set: Accuracy: 791/6800 (12%)
# Test set: Accuracy: 815/6800 (12%)
#
#
# Train Epoch: 41 [(0%)]	Loss: 2.663246
# Train Epoch: 41 [(42%)]	Loss: 2.666668
# Train Epoch: 41 [(83%)]	Loss: 2.677846
# Train set: Accuracy: 2641/20400 (13%)
# Val set: Accuracy: 793/6800 (12%)
# Test set: Accuracy: 841/6800 (12%)
#
#
# Train Epoch: 42 [(0%)]	Loss: 2.675291
# Train Epoch: 42 [(42%)]	Loss: 2.679065
# Train Epoch: 42 [(83%)]	Loss: 2.672030
# Train set: Accuracy: 2545/20400 (12%)
# Val set: Accuracy: 786/6800 (12%)
# Test set: Accuracy: 833/6800 (12%)
#
#
# Train Epoch: 43 [(0%)]	Loss: 2.660955
# Train Epoch: 43 [(42%)]	Loss: 2.671463
# Train Epoch: 43 [(83%)]	Loss: 2.640976
# Train set: Accuracy: 2578/20400 (13%)
# Val set: Accuracy: 788/6800 (12%)
# Test set: Accuracy: 800/6800 (12%)
#
#
# Train Epoch: 44 [(0%)]	Loss: 2.679237
# Train Epoch: 44 [(42%)]	Loss: 2.672749
# Train Epoch: 44 [(83%)]	Loss: 2.650460
# Train set: Accuracy: 2558/20400 (13%)
# Val set: Accuracy: 791/6800 (12%)
# Test set: Accuracy: 818/6800 (12%)
#
#
# Train Epoch: 45 [(0%)]	Loss: 2.666577
# Train Epoch: 45 [(42%)]	Loss: 2.666219
# Train Epoch: 45 [(83%)]	Loss: 2.653918
# Train set: Accuracy: 2620/20400 (13%)
# Val set: Accuracy: 761/6800 (11%)
# Test set: Accuracy: 804/6800 (12%)
#
#
# Train Epoch: 46 [(0%)]	Loss: 2.667186
# Train Epoch: 46 [(42%)]	Loss: 2.673097
# Train Epoch: 46 [(83%)]	Loss: 2.663864
# Train set: Accuracy: 2568/20400 (13%)
# Val set: Accuracy: 790/6800 (12%)
# Test set: Accuracy: 827/6800 (12%)
#
#
# Train Epoch: 47 [(0%)]	Loss: 2.663142
# Train Epoch: 47 [(42%)]	Loss: 2.682350
# Train Epoch: 47 [(83%)]	Loss: 2.647288
# Train set: Accuracy: 2504/20400 (12%)
# Val set: Accuracy: 699/6800 (10%)
# Test set: Accuracy: 782/6800 (12%)
#
#
# Train Epoch: 48 [(0%)]	Loss: 2.675968
# Train Epoch: 48 [(42%)]	Loss: 2.671357
# Train Epoch: 48 [(83%)]	Loss: 2.655711
# Train set: Accuracy: 2602/20400 (13%)
# Val set: Accuracy: 810/6800 (12%)
# Test set: Accuracy: 836/6800 (12%)
#
#
# Train Epoch: 49 [(0%)]	Loss: 2.664795
# Train Epoch: 49 [(42%)]	Loss: 2.673201
# Train Epoch: 49 [(83%)]	Loss: 2.669854
# Train set: Accuracy: 2660/20400 (13%)
# Val set: Accuracy: 806/6800 (12%)
# Test set: Accuracy: 803/6800 (12%)
#
#
# Train Epoch: 50 [(0%)]	Loss: 2.671837
# Train Epoch: 50 [(42%)]	Loss: 2.668393
# Train Epoch: 50 [(83%)]	Loss: 2.658489
# Train set: Accuracy: 2627/20400 (13%)
# Val set: Accuracy: 796/6800 (12%)
# Test set: Accuracy: 805/6800 (12%)
#
#
# Train Epoch: 51 [(0%)]	Loss: 2.660691
# Train Epoch: 51 [(42%)]	Loss: 2.675752
# Train Epoch: 51 [(83%)]	Loss: 2.641513
# Train set: Accuracy: 2518/20400 (12%)
# Val set: Accuracy: 730/6800 (11%)
# Test set: Accuracy: 785/6800 (12%)
#
#
# Train Epoch: 52 [(0%)]	Loss: 2.624851
# Train Epoch: 52 [(42%)]	Loss: 2.669589
# Train Epoch: 52 [(83%)]	Loss: 2.650545
# Train set: Accuracy: 2591/20400 (13%)
# Val set: Accuracy: 823/6800 (12%)
# Test set: Accuracy: 822/6800 (12%)
#
#
# Train Epoch: 53 [(0%)]	Loss: 2.646605
# Train Epoch: 53 [(42%)]	Loss: 2.680864
# Train Epoch: 53 [(83%)]	Loss: 2.651866
# Train set: Accuracy: 2698/20400 (13%)
# Val set: Accuracy: 820/6800 (12%)
# Test set: Accuracy: 826/6800 (12%)
#
#
# Train Epoch: 54 [(0%)]	Loss: 2.642309
# Train Epoch: 54 [(42%)]	Loss: 2.668778
# Train Epoch: 54 [(83%)]	Loss: 2.655053
# Train set: Accuracy: 2636/20400 (13%)
# Val set: Accuracy: 815/6800 (12%)
# Test set: Accuracy: 826/6800 (12%)
#
#
# Train Epoch: 55 [(0%)]	Loss: 2.648262
# Train Epoch: 55 [(42%)]	Loss: 2.676688
# Train Epoch: 55 [(83%)]	Loss: 2.644321
# Train set: Accuracy: 2586/20400 (13%)
# Val set: Accuracy: 803/6800 (12%)
# Test set: Accuracy: 822/6800 (12%)
#
#
# Train Epoch: 56 [(0%)]	Loss: 2.653139
# Train Epoch: 56 [(42%)]	Loss: 2.686675
# Train Epoch: 56 [(83%)]	Loss: 2.649187
# Train set: Accuracy: 2562/20400 (13%)
# Val set: Accuracy: 818/6800 (12%)
# Test set: Accuracy: 818/6800 (12%)
#
#
# Train Epoch: 57 [(0%)]	Loss: 2.657242
# Train Epoch: 57 [(42%)]	Loss: 2.677533
# Train Epoch: 57 [(83%)]	Loss: 2.649287
# Train set: Accuracy: 2639/20400 (13%)
# Val set: Accuracy: 805/6800 (12%)
# Test set: Accuracy: 820/6800 (12%)
#
#
# Train Epoch: 58 [(0%)]	Loss: 2.662015
# Train Epoch: 58 [(42%)]	Loss: 2.661251
# Train Epoch: 58 [(83%)]	Loss: 2.639726
# Train set: Accuracy: 2600/20400 (13%)
# Val set: Accuracy: 826/6800 (12%)
# Test set: Accuracy: 807/6800 (12%)
#
#
# Train Epoch: 59 [(0%)]	Loss: 2.645970
# Train Epoch: 59 [(42%)]	Loss: 2.673564
# Train Epoch: 59 [(83%)]	Loss: 2.675115
# Train set: Accuracy: 2555/20400 (13%)
# Val set: Accuracy: 804/6800 (12%)
# Test set: Accuracy: 837/6800 (12%)
#
#
# Train Epoch: 60 [(0%)]	Loss: 2.655107
# Train Epoch: 60 [(42%)]	Loss: 2.657405
# Train Epoch: 60 [(83%)]	Loss: 2.642625
# Train set: Accuracy: 2585/20400 (13%)
# Val set: Accuracy: 783/6800 (12%)
# Test set: Accuracy: 839/6800 (12%)
#
#
# Train Epoch: 61 [(0%)]	Loss: 2.661585
# Train Epoch: 61 [(42%)]	Loss: 2.677217
# Train Epoch: 61 [(83%)]	Loss: 2.651731
# Train set: Accuracy: 2503/20400 (12%)
# Val set: Accuracy: 779/6800 (11%)
# Test set: Accuracy: 836/6800 (12%)
#
#
# Train Epoch: 62 [(0%)]	Loss: 2.643722
# Train Epoch: 62 [(42%)]	Loss: 2.673784
# Train Epoch: 62 [(83%)]	Loss: 2.633250
# Train set: Accuracy: 2616/20400 (13%)
# Val set: Accuracy: 806/6800 (12%)
# Test set: Accuracy: 840/6800 (12%)
#
#
# Train Epoch: 63 [(0%)]	Loss: 2.653022
# Train Epoch: 63 [(42%)]	Loss: 2.658167
# Train Epoch: 63 [(83%)]	Loss: 2.646958
# Train set: Accuracy: 2662/20400 (13%)
# Val set: Accuracy: 811/6800 (12%)
# Test set: Accuracy: 816/6800 (12%)
#
#
# Train Epoch: 64 [(0%)]	Loss: 2.677600
# Train Epoch: 64 [(42%)]	Loss: 2.683040
# Train Epoch: 64 [(83%)]	Loss: 2.662460
# Train set: Accuracy: 2655/20400 (13%)
# Val set: Accuracy: 833/6800 (12%)
# Test set: Accuracy: 819/6800 (12%)
#
#
# Train Epoch: 65 [(0%)]	Loss: 2.660793
# Train Epoch: 65 [(42%)]	Loss: 2.653194
# Train Epoch: 65 [(83%)]	Loss: 2.664716
# Train set: Accuracy: 2572/20400 (13%)
# Val set: Accuracy: 814/6800 (12%)
# Test set: Accuracy: 830/6800 (12%)
#
#
# Train Epoch: 66 [(0%)]	Loss: 2.648290
# Train Epoch: 66 [(42%)]	Loss: 2.662974
# Train Epoch: 66 [(83%)]	Loss: 2.635043
# Train set: Accuracy: 2627/20400 (13%)
# Val set: Accuracy: 804/6800 (12%)
# Test set: Accuracy: 812/6800 (12%)
#
#
# Train Epoch: 67 [(0%)]	Loss: 2.652860
# Train Epoch: 67 [(42%)]	Loss: 2.662174
# Train Epoch: 67 [(83%)]	Loss: 2.645548
# Train set: Accuracy: 2645/20400 (13%)
# Val set: Accuracy: 814/6800 (12%)
# Test set: Accuracy: 822/6800 (12%)
#
#
# Train Epoch: 68 [(0%)]	Loss: 2.638456
# Train Epoch: 68 [(42%)]	Loss: 2.682107
# Train Epoch: 68 [(83%)]	Loss: 2.625404
# Train set: Accuracy: 2635/20400 (13%)
# Val set: Accuracy: 825/6800 (12%)
# Test set: Accuracy: 816/6800 (12%)
#
#
# Train Epoch: 69 [(0%)]	Loss: 2.646153
# Train Epoch: 69 [(42%)]	Loss: 2.663853
# Train Epoch: 69 [(83%)]	Loss: 2.660536
# Train set: Accuracy: 2680/20400 (13%)
# Val set: Accuracy: 808/6800 (12%)
# Test set: Accuracy: 814/6800 (12%)
#
#
# Train Epoch: 70 [(0%)]	Loss: 2.656243
# Train Epoch: 70 [(42%)]	Loss: 2.678307
# Train Epoch: 70 [(83%)]	Loss: 2.669516
# Train set: Accuracy: 2596/20400 (13%)
# Val set: Accuracy: 719/6800 (11%)
# Test set: Accuracy: 774/6800 (11%)
#
#
# Train Epoch: 71 [(0%)]	Loss: 2.646956
# Train Epoch: 71 [(42%)]	Loss: 2.665431
# Train Epoch: 71 [(83%)]	Loss: 2.618564
# Train set: Accuracy: 2588/20400 (13%)
# Val set: Accuracy: 832/6800 (12%)
# Test set: Accuracy: 824/6800 (12%)
#
#
# Train Epoch: 72 [(0%)]	Loss: 2.663832
# Train Epoch: 72 [(42%)]	Loss: 2.662483
# Train Epoch: 72 [(83%)]	Loss: 2.647496
# Train set: Accuracy: 2527/20400 (12%)
# Val set: Accuracy: 831/6800 (12%)
# Test set: Accuracy: 816/6800 (12%)
#
#
# Train Epoch: 73 [(0%)]	Loss: 2.658230
# Train Epoch: 73 [(42%)]	Loss: 2.671861
# Train Epoch: 73 [(83%)]	Loss: 2.654395
# Train set: Accuracy: 2566/20400 (13%)
# Val set: Accuracy: 801/6800 (12%)
# Test set: Accuracy: 806/6800 (12%)
#
#
# Train Epoch: 74 [(0%)]	Loss: 2.654541
# Train Epoch: 74 [(42%)]	Loss: 2.643744
# Train Epoch: 74 [(83%)]	Loss: 2.651898
# Train set: Accuracy: 2648/20400 (13%)
# Val set: Accuracy: 827/6800 (12%)
# Test set: Accuracy: 813/6800 (12%)
#
#
# Train Epoch: 75 [(0%)]	Loss: 2.666787
# Train Epoch: 75 [(42%)]	Loss: 2.693662
# Train Epoch: 75 [(83%)]	Loss: 2.646178
# Train set: Accuracy: 2530/20400 (12%)
# Val set: Accuracy: 794/6800 (12%)
# Test set: Accuracy: 850/6800 (12%)
#
#
# Train Epoch: 76 [(0%)]	Loss: 2.650906
# Train Epoch: 76 [(42%)]	Loss: 2.677907
# Train Epoch: 76 [(83%)]	Loss: 2.655814
# Train set: Accuracy: 2578/20400 (13%)
# Val set: Accuracy: 831/6800 (12%)
# Test set: Accuracy: 813/6800 (12%)
#
#
# Train Epoch: 77 [(0%)]	Loss: 2.641261
# Train Epoch: 77 [(42%)]	Loss: 2.661346
# Train Epoch: 77 [(83%)]	Loss: 2.644883
# Train set: Accuracy: 2576/20400 (13%)
# Val set: Accuracy: 812/6800 (12%)
# Test set: Accuracy: 808/6800 (12%)
#
#
# Train Epoch: 78 [(0%)]	Loss: 2.642816
# Train Epoch: 78 [(42%)]	Loss: 2.645065
# Train Epoch: 78 [(83%)]	Loss: 2.640892
# Train set: Accuracy: 2636/20400 (13%)
# Val set: Accuracy: 844/6800 (12%)
# Test set: Accuracy: 831/6800 (12%)
#
#
# Train Epoch: 79 [(0%)]	Loss: 2.652895
# Train Epoch: 79 [(42%)]	Loss: 2.650764
# Train Epoch: 79 [(83%)]	Loss: 2.639732
# Train set: Accuracy: 2677/20400 (13%)
# Val set: Accuracy: 824/6800 (12%)
# Test set: Accuracy: 816/6800 (12%)
#
#
# Train Epoch: 80 [(0%)]	Loss: 2.638362
# Train Epoch: 80 [(42%)]	Loss: 2.673512
# Train Epoch: 80 [(83%)]	Loss: 2.628568
# Train set: Accuracy: 2656/20400 (13%)
# Val set: Accuracy: 821/6800 (12%)
# Test set: Accuracy: 814/6800 (12%)
#
#
# Train Epoch: 81 [(0%)]	Loss: 2.650713
# Train Epoch: 81 [(42%)]	Loss: 2.664263
# Train Epoch: 81 [(83%)]	Loss: 2.641384
# Train set: Accuracy: 2630/20400 (13%)
# Val set: Accuracy: 803/6800 (12%)
# Test set: Accuracy: 824/6800 (12%)
#
#
# Train Epoch: 82 [(0%)]	Loss: 2.628385
# Train Epoch: 82 [(42%)]	Loss: 2.659158
# Train Epoch: 82 [(83%)]	Loss: 2.642747
# Train set: Accuracy: 2664/20400 (13%)
# Val set: Accuracy: 837/6800 (12%)
# Test set: Accuracy: 824/6800 (12%)
#
#
# Train Epoch: 83 [(0%)]	Loss: 2.656506
# Train Epoch: 83 [(42%)]	Loss: 2.668065
# Train Epoch: 83 [(83%)]	Loss: 2.653383
# Train set: Accuracy: 2645/20400 (13%)
# Val set: Accuracy: 829/6800 (12%)
# Test set: Accuracy: 822/6800 (12%)
#
#
# Train Epoch: 84 [(0%)]	Loss: 2.636019
# Train Epoch: 84 [(42%)]	Loss: 2.638347
# Train Epoch: 84 [(83%)]	Loss: 2.632344
# Train set: Accuracy: 2567/20400 (13%)
# Val set: Accuracy: 822/6800 (12%)
# Test set: Accuracy: 806/6800 (12%)
#
#
# Train Epoch: 85 [(0%)]	Loss: 2.656408
# Train Epoch: 85 [(42%)]	Loss: 2.655331
# Train Epoch: 85 [(83%)]	Loss: 2.639974
# Train set: Accuracy: 2651/20400 (13%)
# Val set: Accuracy: 837/6800 (12%)
# Test set: Accuracy: 832/6800 (12%)
#
#
# Train Epoch: 86 [(0%)]	Loss: 2.646072
# Train Epoch: 86 [(42%)]	Loss: 2.652849
# Train Epoch: 86 [(83%)]	Loss: 2.636585
# Train set: Accuracy: 2633/20400 (13%)
# Val set: Accuracy: 871/6800 (13%)
# Test set: Accuracy: 837/6800 (12%)
#
#
# Train Epoch: 87 [(0%)]	Loss: 2.651235
# Train Epoch: 87 [(42%)]	Loss: 2.651683
# Train Epoch: 87 [(83%)]	Loss: 2.637643
# Train set: Accuracy: 2645/20400 (13%)
# Val set: Accuracy: 834/6800 (12%)
# Test set: Accuracy: 814/6800 (12%)
#
#
# Train Epoch: 88 [(0%)]	Loss: 2.660051
# Train Epoch: 88 [(42%)]	Loss: 2.670381
# Train Epoch: 88 [(83%)]	Loss: 2.651245
# Train set: Accuracy: 2606/20400 (13%)
# Val set: Accuracy: 831/6800 (12%)
# Test set: Accuracy: 822/6800 (12%)
#
#
# Train Epoch: 89 [(0%)]	Loss: 2.649524
# Train Epoch: 89 [(42%)]	Loss: 2.677567
# Train Epoch: 89 [(83%)]	Loss: 2.647754
# Train set: Accuracy: 2579/20400 (13%)
# Val set: Accuracy: 819/6800 (12%)
# Test set: Accuracy: 806/6800 (12%)
#
#
# Train Epoch: 90 [(0%)]	Loss: 2.638553
# Train Epoch: 90 [(42%)]	Loss: 2.671901
# Train Epoch: 90 [(83%)]	Loss: 2.626996
# Train set: Accuracy: 2668/20400 (13%)
# Val set: Accuracy: 837/6800 (12%)
# Test set: Accuracy: 827/6800 (12%)
#
#
# Train Epoch: 91 [(0%)]	Loss: 2.612171
# Train Epoch: 91 [(42%)]	Loss: 2.647159
# Train Epoch: 91 [(83%)]	Loss: 2.634318
# Train set: Accuracy: 2612/20400 (13%)
# Val set: Accuracy: 823/6800 (12%)
# Test set: Accuracy: 828/6800 (12%)
#
#
# Train Epoch: 92 [(0%)]	Loss: 2.647201
# Train Epoch: 92 [(42%)]	Loss: 2.654059
# Train Epoch: 92 [(83%)]	Loss: 2.616965
# Train set: Accuracy: 2625/20400 (13%)
# Val set: Accuracy: 836/6800 (12%)
# Test set: Accuracy: 810/6800 (12%)
#
#
# Train Epoch: 93 [(0%)]	Loss: 2.656093
# Train Epoch: 93 [(42%)]	Loss: 2.650399
# Train Epoch: 93 [(83%)]	Loss: 2.640369
# Train set: Accuracy: 2601/20400 (13%)
# Val set: Accuracy: 800/6800 (12%)
# Test set: Accuracy: 817/6800 (12%)
#
#
# Train Epoch: 94 [(0%)]	Loss: 2.646046
# Train Epoch: 94 [(42%)]	Loss: 2.649445
# Train Epoch: 94 [(83%)]	Loss: 2.643218
# Train set: Accuracy: 2576/20400 (13%)
# Val set: Accuracy: 810/6800 (12%)
# Test set: Accuracy: 825/6800 (12%)
#
#
# Train Epoch: 95 [(0%)]	Loss: 2.654011
# Train Epoch: 95 [(42%)]	Loss: 2.662202
# Train Epoch: 95 [(83%)]	Loss: 2.657385
# Train set: Accuracy: 2617/20400 (13%)
# Val set: Accuracy: 836/6800 (12%)
# Test set: Accuracy: 795/6800 (12%)
#
#
# Train Epoch: 96 [(0%)]	Loss: 2.637146
# Train Epoch: 96 [(42%)]	Loss: 2.655663
# Train Epoch: 96 [(83%)]	Loss: 2.626678
# Train set: Accuracy: 2616/20400 (13%)
# Val set: Accuracy: 827/6800 (12%)
# Test set: Accuracy: 857/6800 (13%)
#
#
# Train Epoch: 97 [(0%)]	Loss: 2.645485
# Train Epoch: 97 [(42%)]	Loss: 2.682767
# Train Epoch: 97 [(83%)]	Loss: 2.636510
# Train set: Accuracy: 2748/20400 (13%)
# Val set: Accuracy: 878/6800 (13%)
# Test set: Accuracy: 855/6800 (13%)
#
#
# Train Epoch: 98 [(0%)]	Loss: 2.631790
# Train Epoch: 98 [(42%)]	Loss: 2.641110
# Train Epoch: 98 [(83%)]	Loss: 2.652607
# Train set: Accuracy: 2692/20400 (13%)
# Val set: Accuracy: 845/6800 (12%)
# Test set: Accuracy: 852/6800 (13%)
#
#
# Train Epoch: 99 [(0%)]	Loss: 2.618521
# Train Epoch: 99 [(42%)]	Loss: 2.650040
# Train Epoch: 99 [(83%)]	Loss: 2.622682
# Train set: Accuracy: 2752/20400 (13%)
# Val set: Accuracy: 879/6800 (13%)
# Test set: Accuracy: 892/6800 (13%)
#
#
# Train Epoch: 100 [(0%)]	Loss: 2.659689
# Train Epoch: 100 [(42%)]	Loss: 2.660547
# Train Epoch: 100 [(83%)]	Loss: 2.640290
# Train set: Accuracy: 2710/20400 (13%)
# Val set: Accuracy: 860/6800 (13%)
# Test set: Accuracy: 846/6800 (12%)
